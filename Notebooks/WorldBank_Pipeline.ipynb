# %% [markdown]
# # Import libraries

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ### URL Indicator Info JSON and pages
# (There are 330 pages in total)

# %%
url_grl ="http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&page="

# %% [markdown]
# ### Accessing all pages
#
# *pages* is a range from 1 to 330
# <br>
# *urls* is a list, it contains *url_grl* + *page* in *pages*
# <br>
# *all_pages_data* is a list, it contains a list with info from JSON API

# %%
pages = range(1,331)
urls = []
all_pages_data = []

# %%
for page in pages:
    urls.append(url_grl+str(page))

# %%
for url in urls:
    all_pages_data.append(requests.get(url).json())

# %% [markdown]
# Cada dict con info contiene:
# <br>
#
# <p style="text-align: center;">
#     indicador -> [dict con id y value] indicator id Total population
#     <br>
#     country -> [dict con id y value] Country id, country name
#     <br>
#     countryiso3code -> [str] code
#     <br>
#     date -> [str] year
#     <br>
#     value -> [int] total population
#     <br>
# </p>

# %%
list_countries = []

# %%
for i in range(0,329):
    for j in range (0,50):
        if all_pages_data[i][1][j]['country']['value'] not in list_countries:
            list_countries.append(all_pages_data[i][1][j]['country']['value'])

# %%
series_countries = pd.Series(list_countries)

# %%
list_years = []

# %%
for i in range(0,329):
    for j in range (0,50):
        if all_pages_data[i][1][j]['date'] not in list_years:
            list_years.append(all_pages_data[i][1][j]['date'])

# %%
series_year = pd.Series(list_years)

# %%
list_dicts_per_year = []
for year in series_year:
    list_dicts_per_year.append({})

# %%
for i_year in range(len(series_year)):
    for i_pages in range(0, 330):
        for i_page in range(0, len(all_pages_data[i_pages][1])):
            if all_pages_data[i_pages][1][i_page]['date']==series_year[i_year]:
                list_dicts_per_year[i_year].update({
                    all_pages_data[i_pages][1][i_page]['country']['value'] : all_pages_data[i_pages][1][i_page]['value']
                })

# %%
dict_info_per_year = dict()

# %%
for i_year in range(len(series_year)):
    for info in list_dicts_per_year[i_year]:
        dict_info_per_year.update({
            series_year[i_year] : pd.Series(list_dicts_per_year[i_year])
        })

# %%
Indicators_DataFrame = pd.DataFrame(dict_info_per_year)

# %% [markdown]
# Para cada una de las paginas data_per_page (estas son listas, que contienen 1 diccionario con la info de cada pag y 1 lista con de los indicadores)
# <br>
# Hay que acceder a data_per_page \[ 1: \], esa es la info que estará en

# %%
Indicators_DataFrame.describe()
# Out:
#                2021          2020          2019          2018          2017  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   3.223248e+08  3.190983e+08  3.155191e+08  3.118393e+08  3.080704e+08
# std    1.004098e+09  9.950997e+08  9.850384e+08  9.745580e+08  9.637185e+08
# min    1.120400e+04  1.106900e+04  1.095600e+04  1.086500e+04  1.082800e+04
# 25%    1.786038e+06  1.790133e+06  1.788878e+06  1.797085e+06  1.791003e+06
# 50%    1.050577e+07  1.060623e+07  1.044767e+07  1.039533e+07  1.030030e+07
# 75%    6.358833e+07  6.170452e+07  5.987258e+07  6.042176e+07  6.053671e+07
# max    7.888409e+09  7.820982e+09  7.742682e+09  7.661776e+09  7.578158e+09
#
#                2016          2015          2014          2013          2012  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   3.042155e+08  3.003545e+08  2.964856e+08  2.925870e+08  2.886995e+08
# std    9.525129e+08  9.412781e+08  9.299558e+08  9.184860e+08  9.070053e+08
# min    1.085200e+04  1.087700e+04  1.089900e+04  1.069400e+04  1.044400e+04
# 25%    1.777557e+06  1.788196e+06  1.743309e+06  1.697753e+06  1.652717e+06
# 50%    1.032545e+07  1.035808e+07  1.028212e+07  1.014958e+07  9.920362e+06
# 75%    6.062750e+07  6.073058e+07  6.078914e+07  6.023395e+07  5.953972e+07
# max    7.491934e+09  7.404911e+09  7.317509e+09  7.229185e+09  7.140896e+09
#
#        ...          1969          1968          1967          1966  \
# count  ...  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   ...  1.408128e+08  1.377713e+08  1.348350e+08  1.319789e+08
# std    ...  4.450496e+08  4.350875e+08  4.255158e+08  4.162308e+08
# min    ...  5.646000e+03  5.354000e+03  4.930000e+03  4.531000e+03
# 25%    ...  5.875942e+05  5.832700e+05  5.773872e+05  5.691470e+05
# 50%    ...  4.530800e+06  4.450934e+06  4.385700e+06  4.331825e+06
# 75%    ...  3.277149e+07  3.249927e+07  3.209247e+07  3.163010e+07
# max    ...  3.614669e+09  3.540255e+09  3.468457e+09  3.398561e+09
#
#                1965          1964          1963          1962          1961  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291211e+08  1.263792e+08  1.236763e+08  1.209957e+08  1.188268e+08
# std    4.069033e+08  3.980380e+08  3.893042e+08  3.806132e+08  3.738947e+08
# min    4.161000e+03  3.811000e+03  3.481000e+03  3.171000e+03  2.888000e+03
# 25%    5.651150e+05  5.566630e+05  5.449288e+05  5.337595e+05  5.231345e+05
# 50%    4.277636e+06  4.224612e+06  4.139356e+06  4.023896e+06  3.887144e+06
# 75%    3.084892e+07  3.001684e+07  2.914708e+07  2.830289e+07  2.748694e+07
# max    3.328285e+09  3.260518e+09  3.193509e+09  3.126935e+09  3.072511e+09
#
#                1960
# count  2.640000e+02
# mean   1.172187e+08
# std    3.693371e+08
# min    2.646000e+03
# 25%    5.132212e+05
# 50%    3.757486e+06
# 75%    2.670606e+07
# max    3.031565e+09
#
# [8 rows x 62 columns]

# %%
Indicators_DataFrame
# Out:
#                                        2021         2020         2019  \
# Africa Eastern and Southern     702976832.0  685112705.0  667242712.0
# Africa Western and Central      478185907.0  466189102.0  454306063.0
# Arab World                      456520777.0  449228296.0  441467739.0
# Caribbean small states            7481877.0    7444768.0    7424102.0
# Central Europe and the Baltics  101430997.0  102180124.0  102398537.0
# ...                                     ...          ...          ...
# Virgin Islands (U.S.)              105870.0     106290.0     106669.0
# West Bank and Gaza                4922749.0    4803269.0    4685306.0
# Yemen, Rep.                      32981641.0   32284046.0   31546691.0
# Zambia                           19473125.0   18927715.0   18380477.0
# Zimbabwe                         15993524.0   15669666.0   15354608.0
#
#                                        2018         2017         2016  \
# Africa Eastern and Southern     649756874.0  632746296.0  616377331.0
# Africa Western and Central      442646825.0  431138704.0  419778384.0
# Arab World                      432545676.0  423664839.0  415077960.0
# Caribbean small states            7374650.0    7303634.0    7265272.0
# Central Europe and the Baltics  102538451.0  102740078.0  102994278.0
# ...                                     ...          ...          ...
# Virgin Islands (U.S.)              107001.0     107281.0     107516.0
# West Bank and Gaza                4569087.0    4454805.0    4367088.0
# Yemen, Rep.                      30790513.0   30034389.0   29274002.0
# Zambia                           17835893.0   17298054.0   16767761.0
# Zimbabwe                         15052184.0   14751101.0   14452704.0
#
#                                        2015         2014         2013  \
# Africa Eastern and Southern     600008150.0  583650827.0  567891875.0
# Africa Western and Central      408690375.0  397855507.0  387204553.0
# Arab World                      406501999.0  397922915.0  389131555.0
# Caribbean small states            7224602.0    7181044.0    7135884.0
# Central Europe and the Baltics  103257886.0  103496179.0  103713726.0
# ...                                     ...          ...          ...
# Virgin Islands (U.S.)              107712.0     107882.0     108041.0
# West Bank and Gaza                4270092.0    4173398.0    4076708.0
# Yemen, Rep.                      28516545.0   27753304.0   26984002.0
# Zambia                           16248230.0   15737793.0   15234976.0
# Zimbabwe                         14154937.0   13855753.0   13555422.0
#
#                                        2012  ...         1969         1968  \
# Africa Eastern and Southern     552530654.0  ...  167596160.0  162875171.0
# Africa Western and Central      376797999.0  ...  118615741.0  115921723.0
# Arab World                      380383408.0  ...  119061868.0  115729597.0
# Caribbean small states            7088996.0  ...    4883868.0    4813958.0
# Central Europe and the Baltics  103935318.0  ...   98606630.0   97884022.0
# ...                                     ...  ...          ...          ...
# Virgin Islands (U.S.)              108188.0  ...      60300.0      55700.0
# West Bank and Gaza                3979998.0  ...          NaN          NaN
# Yemen, Rep.                      26223391.0  ...    6673981.0    6515904.0
# Zambia                           14744658.0  ...    4159007.0    4029173.0
# Zimbabwe                         13265331.0  ...    5044163.0    4886347.0
#
#                                        1967         1966         1965  \
# Africa Eastern and Southern     158313235.0  153955516.0  149742351.0
# Africa Western and Central      113319950.0  110798486.0  108336203.0
# Arab World                      112499764.0  109394536.0  106444103.0
# Caribbean small states            4743053.0    4670465.0    4596245.0
# Central Europe and the Baltics   97043270.0   96146336.0   95440988.0
# ...                                     ...          ...          ...
# Virgin Islands (U.S.)               49100.0      46200.0      43500.0
# West Bank and Gaza                      NaN          NaN          NaN
# Yemen, Rep.                       6368014.0    6228430.0    6097298.0
# Zambia                            3901288.0    3777680.0    3658024.0
# Zimbabwe                          4734694.0    4588529.0    4447149.0
#
#                                        1964         1963         1962  \
# Africa Eastern and Southern     145605995.0  141630546.0  137835590.0
# Africa Western and Central      105959979.0  103667517.0  101445032.0
# Arab World                      103618568.0  100892507.0   98268683.0
# Caribbean small states            4520592.0    4443544.0    4366420.0
# Central Europe and the Baltics   94715795.0   93840016.0   93009498.0
# ...                                     ...          ...          ...
# Virgin Islands (U.S.)               40800.0      39800.0      35000.0
# West Bank and Gaza                      NaN          NaN          NaN
# Yemen, Rep.                       5973803.0    5860197.0    5753386.0
# Zambia                            3542764.0    3431381.0    3323427.0
# Zimbabwe                          4310332.0    4177931.0    4049778.0
#
#                                        1961         1960
# Africa Eastern and Southern     134169237.0  130692579.0
# Africa Western and Central       99314028.0   97256290.0
# Arab World                       95760348.0   93359407.0
# Caribbean small states            4289429.0    4209141.0
# Central Europe and the Baltics   92232738.0   91401764.0
# ...                                     ...          ...
# Virgin Islands (U.S.)               34300.0      32500.0
# West Bank and Gaza                      NaN          NaN
# Yemen, Rep.                       5646668.0    5542459.0
# Zambia                            3219451.0    3119430.0
# Zimbabwe                          3925952.0    3806310.0
#
# [266 rows x 62 columns]
